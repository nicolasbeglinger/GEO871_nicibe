# %%
import pandas as pd
import geopandas as gpd
from pprint import pprint
# import matplotlib.pyplot as plt
# import contextily as cx
import folium
import html2text
import os

import math

import inspect
import re

# %% [markdown]
# Define function to debug

# %%
def prinfo(*args, **kwargs):
    frame = inspect.currentframe().f_back
    s = inspect.getframeinfo(frame).code_context[0]
    r = re.search(r"\((.*)\)", s).group(1)
    vnames = r.split(", ")

    if 'newline' in kwargs:
        newlinestring = "\n" if kwargs['newline'] else ""
    else:
        newlinestring = ""

    for i, (var, val) in enumerate(zip(vnames, args)):
        print(f"{var} = {newlinestring}{val}")

# %% [markdown]
# Define function to give information about the progress of reading the csv

# %%
def read_csv_in_chunks(path, n_lines, **read_params):
    if 'chunksize' not in read_params or read_params['chunksize'] < 1:
        read_params['chunksize'] = 80000

    chunks = [0] * math.ceil(n_lines / read_params['chunksize'])

    for i, chunk in enumerate(pd.read_csv(path, **read_params)):
        percent = min(((i + 1) * read_params['chunksize'] / n_lines) * 100, 100.0)
        print("#" * int(percent), f"{percent:.2f}%", end='\r', flush=True)
        chunks[i] = chunk
    
    print()
    print("Now concatenating chunks...")
    df = pd.concat(chunks, axis=0)
    del chunks
    print("Finished!")
    return df

# %%
gaz = 'nga'
textfile = "data/texts/aid_wiki.txt"

# IMPORTANT: try the package nltk (natural language processing)

url = 'https://www.theguardian.com/global-development/2021/dec/21/uk-accused-of-abandoning-worlds-poor-as-aid-turned-into-colonial-investment'
text_save_path = f"data/texts/autosave/lastText_{url[-20:]}"
# url = "https://www.theguardian.com/world/2021/oct/21/cuts-to-overseas-aid-thwart-uk-efforts-to-fight-covid-pandemic"



if gaz == "nga":
    gazetteerpath = "data/nga/countries_administrative.csv"
    indexOfLat = 4
    indexOfLon = 5
    n_lines =  484618 #for nga administrative
    # n_lines =  284485 #for nga administrative approved
    # n_lines = 7866485 #for nga administrative populated
    nameCol = "SORT_NAME_RO" # for nga

elif gaz == "geonames":
    gazetteerpath = "data/geonames/allCountries_cleaned.csv"
    indexOfLat = 5
    indexOfLon = 6
    n_lines = 6974472
    nameCol = "name"

# %% [markdown]
# Read gazetter data (csv) and save placenames in a list

# %%
if gaz == "countries":
    countrynames = pd.read_csv("data/geodict_github/countrynames.csv", names=["short", "long"])
    countrypositions = pd.read_csv("data/geodict_github/countrypositions.csv", names=["short", "lat", "lon"])

    df_gazetteer = countrynames.merge(countrypositions, on="short")
    df_gazetteer.long = df_gazetteer.long.str.strip()
    indexOfLat = 2
    indexOfLon = 3
    n_lines = 240
    nameCol = "long"
    
else:
# read in the gazetter csv
    df_gazetteer = read_csv_in_chunks(
        path = gazetteerpath,
        n_lines = n_lines,
        low_memory=False)

# save all placenames as a list
placenames = [country.strip() for country in df_gazetteer[nameCol].tolist()]

prinfo(placenames[:5])
# Out:
# #################################################################################################### 100.00%
# Now concatenating chunks...
# Finished!
# placenames[:5] = ['ARUBA', 'LANDARUBA', 'ARUBA', 'COUNTRYOFARUBA', 'ARUBA']

# %% [markdown]
# Import textfile or call the html2text function to extract the text from a given url and save it for next use

# %%
if textfile:
    with open(textfile, "r") as wiki:
        lines = wiki.readlines()
    allWords = []
    for line in lines:
        allWords.extend(line.strip().split(" "))

else:
    if not os.path.exists(text_save_path):
        allWords = html2text.html2text(url=url).split(" ")

        with open(text_save_path, "w") as lt:
            lt.write(" ".join(allWords))

    else:
        with open(text_save_path, "r") as lt:
            allWords = lt.read().split(" ")

    # # include only capital words in list
    # allWords = [word for word in allWords if word[0].isupper()]

# %% [markdown]
# Import most common words

# %%
# # 500
# common_set = [str(word).upper() for word in list(pd.read_csv("data/500_MostCommonWords.csv", skiprows=4, sep=";", header=None)[1].values)]

# 1000
with open("data/1000_MostCommonWords.txt", "r") as common_1000:
    common_set = {word.strip().upper() for word in common_1000.readlines()}

# %%
placenames_set
# Out:
# {'DESATONDANOUWSATU',
#  'MUNICIPIODEMARUMBI',
#  'EREBANGO',
#  'PEIHUOSHANG',
#  '北漳',
#  'MUNICIPIODEPINHEIROPRETO',
#  '王皮溜镇',
#  'KECAMATANKOTASUMENEP',
#  'HSIHANLING',
#  '发窝乡',
#  'LANDKREISWUNSIEDELIMFICHTELGEBIRGE',
#  'TZULINGPU',
#  'DAURALOCALGOVERNMENTAREA',
#  '풍덕리',
#  'LANGEH',
#  '柘溪镇',
#  'DESAWOLOMAPA',
#  'PAIKUAN',
#  'XATRUNGSON',
#  'XEMIRXEK',
#  'NKOMANGOMBE',
#  'MANGNONGZHEN',
#  '신효리',
#  '금사리',
#  'CALAKMUL',
#  'DAEBANG',
#  'ALTEPEXI',
#  'TUNLITSUN',
#  'BATANGAN',
#  'DAIRADEBENIABBES',
#  'MUNICIPIODEOUROFINO',
#  '花丛',
#  '河口街道',
#  'CAGWAIT',
#  '회덕b동',
#  'SANLORENZORUIZUNO',
#  'CHONDONGNI',
#  'DESATANDOYONDO',
#  'DESABALOREJO',
#  'QINGTONGXIASHI',
#  'BOEWEINTOBA',
#  '涛圩',
#  'GURVANZAGALSUM',
#  'KENYAMONTA',
#  '太平里乡',
#  'CARRASCO',
#  '花山',
#  'JINNIU',
#  '丈亭镇',
#  'ITAPICURU',
#  '东川镇',
#  '방림면',
#  'DEPARTEMENTDESARDENNES',
#  'SORIOAN',
#  '三官',
#  '吉潭镇',
#  '栏杆集镇',
#  '荣华乡',
#  'YABON',
#  '전진리',
#  '美里町',
#  'MUNICIPIODESANTODOMINGOALBARRADAS',
#  'KABUPATENTEGAL',
#  'KAMPUNGKOMBAMA',
#  'NORTHCADULAWAN',
#  'TAPAUA',
#  'HSUCHIATO',
#  'あきるのし',
#  '전호리',
#  'WEERT',
#  'DESATOKKONAN',
#  'WUXUZHEN',
#  'WANRONGXIAN',
#  'YEONGDEUNGPObDONG',
#  'LOCHOUCHEN',
#  '老城区',
#  '杨公庙乡',
#  'COMUNACAPALNAS',
#  'KOTTING',
#  'SAJA',
#  'CHUSALLI',
#  'MUNICIPIODEMARVERMELHO',
#  'KEUMIEE',
#  'KELURAHANSUNTERJAYA',
#  'IQLIMJARADAH',
#  'DINGCHENGQU',
#  'MAHAICAUNITYLOCALGOVERNMENTDISTRICT',
#  'BOKDEOKRI',
#  'MAFANGZI',
#  'GUANTIANZHEN',
#  'MUNICIPIODEALTOSDELROSARIO',
#  'KABUPATENEMPATLAWANG',
#  'GAKURWESUBLOCATION',
#  'PIXIAN',
#  'OKHTYRSKYYRAYON',
#  '胡家河',
#  'كەركوك',
#  'DEPARTAMENTODELIMAYMAHUIDA',
#  'ZONGZHAIXIANG',
#  '卫固镇',
#  'ASTEN',
#  'LINGHSIEN',
#  'DESACIKUBANG',
#  'DESADOMISILMOONOW',
#  'DESATOMBOLIKATSELATAN',
#  '덕화리',
#  '구만리',
#  'CHUKCHOLLI',
#  'SHAHRESTANEBAKHARZ',
#  'TONGNIPTONG',
#  'XACOCLAU',
#  'CHATHAMISLANDSTERRITORY',
#  'LAZDIJURAJONOSAVIVALDYBE',
#  'KAMPUNGSRALALA',
#  'DESASATTOKO',
#  'DESABATUGANDAPERMAI',
#  'SHAHUXIANG',
#  'OCHEONRI',
#  'MUNICIPIODEDEGOLLADO',
#  'XINGSHAN',
#  'SHIHHSIATSUN',
#  'PRUDENTEDEMORAIS',
#  '태화동',
#  'CERCLEDEBEJAAD',
#  'IIDASHI',
#  '李典',
#  'DESALEBAKKEPUH',
#  'ITAIPULANDIA',
#  'JIASHIXIAN',
#  'DESAKLIDANGLOR',
#  '稻城县',
#  'LIANGGEZHUANG',
#  '富士見村',
#  'ANHUAZHEN',
#  'TUMENPU',
#  'MANIKANGO',
#  'ALUTHTOTA',
#  '勒秀乡',
#  'COLLECTIVITETERRITORIALEDEMARTINIQUE',
#  'CHILGOLbDONG',
#  '古里乡',
#  'SOLUM',
#  '成田镇',
#  'KUMSURI',
#  'NAMGANGNODONGJAGU',
#  'NAZHANG',
#  'SUMINOCHO',
#  '铎山镇',
#  'DESANGENDEN',
#  'ГрадскаОпштинаСавскиВенац',
#  '青山铺',
#  'SHAHRESTANESHAHREBABAK',
#  'ПРОМЫШЛЕННЫЙРАЙОН',
#  'ALJUMHURIYAHALARABIYAHASSURIYAH',
#  'PHUONGHOALU',
#  'DEMARCACIONTERRITORIALLAMAGDALENACONTRERAS',
#  '那須郡',
#  'GILUTONGAN',
#  'KINGAMPHOENAMKHUN',
#  'YAKUMO',
#  'YENPIENHSIEN',
#  'KECAMATANKOTASEKAYU',
#  '鎮興里',
#  'وازهخواه',
#  'DESABORIMATANGKASA',
#  '蒋村镇',
#  'SOCIALISTPEOPLESLIBYANARABJAMAHIRIYA',
#  'THATUN',
#  'LAOCHUNG',
#  'TUNGNANLI',
#  'KYONGJUGUN',
#  '许家桥回族维吾尔族乡',
#  'SHAHRESTANETORBATEJAM',
#  '浪河',
#  'MULLAEDONG',
#  'BALEGEM',
#  '梁堤头',
#  'ITAKOSHI',
#  'YABUGUN',
#  'CONCELHODADAMBA',
#  'KOMUNAULEZ',
#  'CHINCHIACHUANG',
#  'DESAPAITAN',
#  'TANTSUN',
#  'ЫсыкКөлОблусу',
#  'SHUIYUGUANZHEN',
#  'BALADIYATMAWLAYIDRISZARHUN',
#  'KELURAHANPATIHANWETAN',
#  'PRZEMYSLCOUNTY',
#  'KHAMTIDISTRICT',
#  'KORAI',
#  'NAHIYATARIQAH',
#  'DATANG',
#  'YEBUKOU',
#  'SHAJINTANXIANG',
#  'HAOSIBUERDUSUMU',
#  'JINGUANG',
#  'BAHAGIANKEEMPAT',
#  'POLOSSU',
#  'KAUNERTAL',
#  '백암읍',
#  'MUNICIPIODEPOCOES',
#  '大庙乡',
#  'LUNGCHANG',
#  'HOTSECHUANCHU',
#  'KISSIKAMA',
#  'HAPSONGNI',
#  'PHUONGLACDAO',
#  'PUXIONGXIANG',
#  'PINNIANGCHEN',
#  'BAIBAN',
#  'DESAMALAKA',
#  '목육동',
#  'POLLINKHOVE',
#  'DESAMAAR',
#  'ENASUBLOCATION',
#  'MENTOUKOUCHU',
#  '上山市',
#  'GATAQU',
#  'GWANGEUMRI',
#  'DISTRITODEJANGAMO',
#  'KOMUNASUC',
#  'WANGOUMEN',
#  'MUNICIPIODEVALLEDELGUAMUEZ',
#  'DESAKALIWADAS',
#  'HAIYANMIAO',
#  'SOEMBERGEMPOL',
#  'EASTSHEWA',
#  'DESAAMBUAUTOGO',
#  'DHEKUNUSARAHAHDHU',
#  'DAIRADELAOUINET',
#  'COMUNABALAUSERI',
#  '江戸川区',
#  '拉如',
#  'YUELIN',
#  'ASHSHAMIYAQADHA',
#  'DABINXIANG',
#  '高墟',
#  'SVEITARFELAGIDHVOGAR',
#  'SALAZARSANJOSE',
#  'TUSHIHCHANG',
#  'PROVINCIADELAMBAYEQUE',
#  'DIMOSIRAKLEIAS',
#  'NZIUSUBLOCATION',
#  'TOMIZAWACHO',
#  'CHHATAWA',
#  'DAHAMGAMA',
#  'ELNAYAR',
#  'GENERALBALLIVIAN',
#  'MUNICIPIODEPALMEIRADASMISSOES',
#  'PECINCI',
#  'HAUKADALSHREPPUR',
#  '张祠',
#  '松树沟乡',
#  'NANPAIHEZHEN',
#  'KPI',
#  'MANGSHIH',
#  'TAFUNSAK',
#  'MUNICIPIODEOTZOLOTEPEC',
#  'DEPARTAMENTODELEVENTUE',
#  'DONGBAHAO',
#  'AMPHOEPAKPHAYUN',
#  'AZCAPOTZALCO',
#  'لواءكفرنجة',
#  'USTTSILEMSKIYRAYON',
#  '界石铺',
#  '齐云山',
#  'TOYOYAMA',
#  'ΑγίαΜαρινούδα',
#  'WANHSIENSHIH',
#  'MIDDLEFLY',
#  'XUNGMAI',
#  'AZNA',
#  'العطفين',
#  '화양동',
#  'MANALOG',
#  '刘店镇',
#  'KAOLIMENTSUN',
#  'YAVOROVSKIYRAYON',
#  'DODOMAMAKULU',
#  '天星寺镇',
#  'SHINSEIMURA',
#  'MINAMIAZUMIGUN',
#  'TOULO',
#  'CHYANGRE',
#  'MATSUMOTO',
#  'TATSUYAMAMURA',
#  'MUNICIPIODEPONTALINDA',
#  'SANTAMARIADEITABIRA',
#  'DEMOCRATICREPUBLICOFAFGHANISTAN',
#  'CHARDARINSKIYRAYON',
#  'SURRYHILLS',
#  'DAPINGSHANZHEN',
#  'BAIZHANGXIANG',
#  'DAEBANGRI',
#  '永鎮村',
#  '忠南',
#  'BALADIYATARRISH',
#  'ZARECHNYYRAYON',
#  'UNGCHON',
#  'MUKIME',
#  'DESABONE',
#  '川街乡',
#  'XIABU',
#  'MARASVILAYETI',
#  'BOKOMUDISTRICT',
#  'LUNGSODNGLIGAO',
#  'KELURAHANARGAPURA',
#  'CABAROANLAUD',
#  'JINMANTANG',
#  'RIJNSBURG',
#  '翟坡镇',
#  'LANUZA',
#  'BUTEGA',
#  'อำเภอโกสุมพิสัย',
#  'GYEYANGIDONG',
#  'STANDREW',
#  'KUHMOINEN',
#  'PROVINCIADEPONTEVEDRA',
#  '宁郭镇',
#  'DESATENGGELANG',
#  'HORADDZYARZHYNSK',
#  'KAMPUNGWUNUME',
#  'WILAYATARYANAH',
#  '木卓',
#  'SUNJIABA',
#  'HUCUNXIANG',
#  'CHUSEINANDO',
#  'SANJUANJUQUILAVIJANOS',
#  'DESAWAILAWA',
#  '归流河',
#  'CAIDATDEDKHISSA',
#  'WULANHADAXIANG',
#  'シブヤク',
#  '犁头',
#  '남강로동자구',
#  'КрасногвардійськийРайон',
#  'INDEPENDENTSTATEOFSAMOA',
#  'LIANGJIAMANZUXIANG',
#  'PROVINCIADELAPAMPA',
#  'CAISANGHUZHEN',
#  '통현리',
#  'YUOMYON',
#  'HSIACHIAOSHIH',
#  '曲鲁海乡',
#  'DESAAMERTHABUANA',
#  'REGIONDUCENTRESUD',
#  '扶平',
#  'PYEONGCHONRI',
#  'العبدة',
#  'SIDIKAN',
#  '长集镇',
#  'SAMOA',
#  'LINGAY',
#  '康厝',
#  'DESAKARANGMLATI',
#  'CHIKSANMYON',
#  'MUNICIPIODEPEIXE',
#  'MASANJIA',
#  'UZUNTUMANI',
#  '장호원읍',
#  'KEKSGOLMSKIYRAYON',
#  'WANLONGSHANXIANG',
#  'DESAPALELEH',
#  'DISTRIKBUK',
#  'LEMBANGLETEK',
#  'DISTRIKNABUNAGE',
#  'AMPHOESABOT',
#  'MUNICIPALITYOFKWAJALEIN',
#  'DESAMUARA',
#  'KELURAHANTIKALAARES',
#  '宁江乡',
#  'NINGGU',
#  '汉南区',
#  'BRYANSKOBLAST',
#  'KETMENTYUBINSKIYRAYON',
#  'MUKUKUTU',
#  'AYAKOZQALASY',
#  'BARIREGION',
#  '新苏莫',
#  '陈二铺',
#  'BAYANONJUULSUM',
#  '方家乡',
#  'MOHAFAZATELISKANDARIYA',
#  '감봉리',
#  'XACAMTHANHBAC',
#  'SHIZHUQIAO',
#  'HSIHOCHEN',
#  'CHANGFUZHEN',
#  'LIULIHEZHEN',
#  '孔村镇',
#  'LATABAN',
#  'SHANGCHENGXIAN',
#  '福永街道',
#  'DESAPOLOPADANG',
#  'XIANXIAXIANG',
#  'GEMEENTEDENEKAMP',
#  'OPSTINABREZICE',
#  '加尤',
#  'fECHARRETTE',
#  '色乡',
#  '西泽乡',
#  '刘田各庄镇',
#  'COMMUNEDEDRUELLEBALSAC',
#  '洞阳',
#  'DESALEUWIBUDAH',
#  'DESAGURANTENG',
#  'LOWERRIVERREGION',
#  '任寨',
#  'LANDKREISDAUN',
#  'BEYANKHE',
#  'DESADUKUHLOR',
#  'TULSKAYAOBLAST',
#  'COMUNACHIESD',
#  'KOTAMADYAMADIUN',
#  'LAVACHERIE',
#  'PUXINANA',
#  '烟庄',
#  'MUHAFAZATRUMAH',
#  'JAGGYEXIANG',
#  'BACHNGOC',
#  'CAMESTIZOAN',
#  'HEXIANGQIAOZHEN',
#  '두루동',
#  'DESAPLOSOGENUK',
#  'NINGTANGZHEN',
#  'PURWAKARTA',
#  'TEGUETE',
#  'DESACIMEKAR',
#  'بامەڕنى',
#  'KELURAHANSELAPAJANGJAYA',
#  'SIEHELI',
#  'MUNICIPIODEEVINAYONG',
#  '扬州市',
#  '미아일동',
#  'YAKKABOGHTUMANI',
#  'LOMBARDSIJDE',
#  '劲涛镇',
#  'TAIYIGONG',
#  'GICHAGIINISUBLOCATION',
#  'KELURAHANCIRANGRANG',
#  'MEDIRIGIRIYA',
#  '秀洲',
#  'ONNAMURA',
#  'QINGJIE',
#  'TABIO',
#  'НОГЛИКСКИЙРАЙОН',
#  'LUTANGXIANG',
#  'XADONGVAN',
#  'TROISIEMEMORNEABRULER',
#  '久社',
#  '水道',
#  'TALONGONAN',
#  'HSIAOPATZU',
#  'DESASUKOREJOKIDUL',
#  'REGIONDUGONTOUGO',
#  'MUNICIPIODECABACEIRASDOPARAGUACU',
#  'KWONGWANNI',
#  'PIJNACKERNOOTDORP',
#  'OEGUNGNI',
#  'LAOXIALUJIEDAO',
#  'WEILE',
#  'DOHWADONG',
#  'DESAOLLOTDUA',
#  '袁店乡',
#  'DESATALAGAWANGI',
#  'PROVINCEDUGANZOURGOU',
#  'SANCHEONGGUN',
#  'KAMPUNGULUM',
#  'XIAZAO',
#  'IGDIRILI',
#  '金珠区',
#  'DESAHODOPANAULI',
#  'قيادةإثنينأملوتنكرفا',
#  'DAERAHTINGKATIKALIMANTANTIMUR',
#  'DESABASSEANG',
#  'KOMBESUBLOCATION',
#  'BHIRKOT',
#  'KELURAHANASTINA',
#  'JANLUD',
#  'قيادةتازروت',
#  'PROVINCIADESULLANA',
#  'MAOSHAN',
#  'KECAMATANAMANUBANTENGAH',
#  'COMUNAGENERALSCARISOREANU',
#  '岩水',
#  'UDIHITIMULLA',
#  '关家川乡',
#  'XIYINGMENJIEDAO',
#  'HUASHIXIAZHEN',
#  'SINPYONG',
#  'BASHKIAESARANDES',
#  'KELURAHANWAWOMBALATA',
#  'WENCHANGHSIEN',
#  'ACKAS',
#  '西湾',
#  '紫荆关',
#  'PANGCAYANAN',
#  'DESATUNASBARU',
#  'JUNGGYEeDONG',
#  '岗巴',
#  'XUJIAQIAOHUIZUUYGURZUXIANG',
#  'YUCHIENHSIEN',
#  'KULEBAKSKIYRAYON',
#  'TZUYANGCHEN',
#  'BONGABON',
#  'ШАРКАЎШЧЫНСКІРАЁН',
#  'SAWARASHI',
#  'MUNAMRI',
#  'COMMUNEDAMMIMOUSSA',
#  '李家寨',
#  'COVENAS',
#  'QADABANIYAS',
#  'BERNAYSAINTMARTIN',
#  'XATINHMINH',
#  'MUNICIPIODEAPULO',
#  'BEOLBANGRI',
#  'TELIYA',
#  'NANJOKA',
#  'JIANGYINSHI',
#  'PINGCHANGGUAN',
#  'KAMISUWAMACHI',
#  'DESASANGLEPOPONGAN',
#  'SAERYANGNI',
#  '杨柑',
#  'YUNGANXIANG',
#  'DAISHINRI',
#  '嘉乐',
#  'RUIFANGZHEN',
#  '刘店子',
#  'DESASINGA',
#  '东山乡',
#  'BUGOKbDONG',
#  'DESACIRAMAHILIR',
#  '大甸乡',
#  '大银镇',
#  'DESAKERAMBITAN',
#  'GALATHARA',
#  'VINHLONG',
#  '古荡镇',
#  'COMUNAGEMENELE',
#  'XAVANMAI',
#  'TRETIRAYONDIMITROVSKI',
#  'KELURAHANWONOKUSUMO',
#  'JANJA',
#  'AKARAPARISH',
#  'TWINPEAKS',
#  'THITRANANTHI',
#  'AMPHOETHAUTHEN',
#  'SKJERVOY',
#  '环通乡',
#  'ARRONDISSEMENTDELACALLE',
#  '高码头',
#  '罐坝乡',
#  'قيادةأولادإفريحةعينبلال',
#  'BILSTAIN',
#  'MUNICIPIODEARCOSDECANASI',
#  'VELDWEZELT',
#  '宣恩',
#  'OKAWAGUN',
#  'KIRIROM',
#  'DELEGATIONDELAGOULETTE',
#  '城南乡',
#  '宅吉',
#  'ALAMLUK',
#  'ALBAY',
#  'KINAWAHAN',
#  'YAZHOU',
#  'IZUDISTRICT',
#  '中洲',
#  'SAINEIMEN',
#  'BAGHCHAUDA',
#  'オンジュクマチ',
#  '柴集镇',
#  '소정리',
#  'PANSHUI',
#  '丙谷',
#  '시왕리',
#  '南澳街道',
#  'BISARBHORA',
#  'المضيلة',
#  'بايقۇرۇت',
#  'دائرةشيشاوة',
#  'HSISHE',
#  'ZHEGOU',
#  '库尔勒市',
#  'KAMBATA',
#  '堂邑',
#  'DUNSHANGXIANG',
#  'DEPARTEMENTDULOMETDJEREM',
#  'MUNICIPIOJOSETADEOMONAGAS',
#  '渔峡口镇',
#  'HSINTSUNSHIH',
#  '农丰满族锡伯族镇',
#  'IMALATTANJAHASILA',
#  'BAYBAYTANZA',
#  '蹈谷',
#  'HOUYANJIZHEN',
#  'MUNICIPIODEJITOTOL',
#  'DESADUNGKEAN',
#  'COMUNAOPRISORU',
#  'LABONGOAMIDA',
#  'GEMEENTEWESTSTELLINGWERF',
#  'RODNIKOVSKIYRAYON',
#  '西庙岗乡',
#  'NYABWAY',
#  '吴小街乡',
#  '济阳',
#  'CARMODOPARANAIBA',
#  'KANEL',
#  'KECAMATANMOYOHILIR',
#  'BARITPANDAN',
#  'DESAPEKUNDEN',
#  'NORTHABACO',
#  'YUJIANXIANG',
#  'WUBULINSUMU',
#  'SHIWEI',
#  'MUNICIPIODEBELAVISTADOTOLDO',
#  'いいづなまち',
#  'DAEWOLRI',
#  '부촌리',
#  'الهوارية',
#  'DESATARAITAK',
#  '新房子镇',
#  'YANMENKOUZHEN',
#  'THANHPHOVUNGTAU',
#  'TURGENSUM',
#  'ITUMUTA',
#  'ALJOOF',
#  'SAUE',
#  'HITASHI',
#  '犬上郡',
#  'KUAM',
#  'YUANJIAXIANG',
#  'EOEUNDONG',
#  '中泉乡',
#  'GUANGCHENZHEN',
#  'قيادةأهلتاوريرت',
#  'IGLIMBULMAN',
#  'ASTANA',
#  'MUNICIPIODESOLOSUCHIAPA',
#  'JAOHO',
#  'VINTO',
#  'PINGLEHSIEN',
#  'YEONSANSAMDONG',
#  'HUANCANE',
#  'BERNABE',
#  'PANDUZHEN',
#  'CONTAECHILLMHANTAIN',
#  'LANDKREISNORDVORPOMMERN',
#  'ITENDE',
#  'LUACANO',
#  'MOCUBELA',
#  'DELEGATIONDEGABES',
#  '漕桥',
#  'CABIGBIGAAN',
#  'DESATOBONGON',
#  '瓦寨',
#  'DESAWAWOBILI',
#  'ΠΕΡΙΦΕΡΕΙΑΚΉΕΝΌΤΗΤΑΕΥΒΟΊΑΣ',
#  'HONAMDONG',
#  'TANGXIANZHEN',
#  'DESALUMBEWE',
#  'DONGPUZHEN',
#  'DISTRIKWARIS',
#  'YOMJU',
#  '涌泉庄乡',
#  '东枣园乡',
#  '拉利',
#  'ВоронежскаяОбласть',
#  'KELURAHANKEJAMBON',
#  'COMMUNEDEVENTENAC',
#  'قضاءالكاظمية',
#  'SAMEKAWAMURA',
#  'SHEYPENI',
#  'SONGJAE',
#  'BEGEMEDIR',
#  '琅琊区',
#  'KYUHOJIMURA',
#  'KECAMATANTANJUNGSARI',
#  'HUODEHONG',
#  'COMUNACIUMATI',
#  '司前',
#  'DEPARTAMENTODEBELEN',
#  'TALASEADISTRICT',
#  'POLA',
#  'KAMPUNGPEPERA',
#  'REPUBLICOFTURKEY',
#  'TIANMA',
#  'APKUJONGDONG',
#  'KAMSAMBA',
#  '沙洛',
#  'KELURAHANNOBOREJO',
#  'GEMEENTEGAASTERLAND',
#  '普陀山镇',
#  'WANGQIANSIZHEN',
#  'MUNICIPIODECONCEICAODABARRA',
#  'METIYAMPOTA',
#  'SIYAMBALANDUWA',
#  '葛塘',
#  'TACHUHSIEN',
#  '西鹅乡',
#  '天池店乡',
#  '外井沟乡',
#  'چوره',
#  'WOJEWODZTWOKOSZALINSKIE',
#  'DEPARTEMENTDILLELA',
#  'EASTMADICOUNTY',
#  'SHINOBUGUN',
#  'DESAPUUDONGI',
#  'WEIMINZHEN',
#  'KINGAMPHOELANGU',
#  'CHANGKANG',
#  '青化',
#  'HOSHANHSU',
#  'MOBARAKEH',
#  'MORDOVSHCHIKOVSKIYRAYON',
#  'SHIKOTISUBLOCATION',
#  '赶场乡',
#  '향정동',
#  'KEIKYA',
#  'CANTONDARGOVIE',
#  'KELURAHANMARGAWATI',
#  'DESASENGKOL',
#  'NIIZURUMURA',
#  'ARKEL',
#  'DESAGEMIRIH',
#  'SHIZIMIAO',
#  'SHAHDADKOT',
#  '宜东镇',
#  'DESACISUNGSANG',
#  'BUKSAMRI',
#  'BIHARU',
#  'THITRANPHATDIEM',
#  '社梁乡',
#  'SANOKOLEMA',
#  '순천리',
#  'DESARANTEPUANG',
#  'TURKEY',
#  'MUNICIPIODEARROIODOSAL',
#  'JIWEI',
#  'MINASGERAIS',
#  'BIESMESOUSTHUIN',
#  'FUSHAZHEN',
#  '凤呜镇',
#  '柳树沟',
#  'JINJIANGXIAN',
#  'PREFECTUREDEMEKNES',
#  '刘村',
#  'WANGJIAWANXIANG',
#  'ASLUM',
#  'KHASYNSKIYRAYON',
#  'KECAMATANKADIPATEN',
#  'RIBEIRAOCORRENTE',
#  'XIAGEZHUANGZHEN',
#  'HULYAYPILSKYYRAYON',
#  'MIRANDADOCORVO',
#  'MIYAGAWA',
#  'MONIATIS',
#  '华强',
#  'DEPARTEMENTDELHERAULT',
#  'TOUTSUN',
#  'NORCHINCHAS',
#  'XINPINGYIZUDAIZUZIZHIXIAN',
#  'KELURAHANMANTOBUA',
#  '水月寺',
#  'NEER',
#  '达塘',
#  'POTANGXIANG',
#  'XIAZAYU',
#  'ISLADEPASCUA',
#  'XALECHANH',
#  'RUANZHUANG',
#  'COMUNAZAGRA',
#  'SHUANGDUIXIANG',
#  'KUEISHANHSIANG',
#  'CLAVERIA',
#  '古塘',
#  'MUNICIPIODEBEJUCAL',
#  'SSANGCHAENGMYON',
#  'LIUJIANG',
#  'HAYRHANDULAANSUM',
#  'JOSEFALCON',
#  'LENINABADOBLAST',
#  '诺水河',
#  '河夹镇',
#  'DESAGOLOROS',
#  'HASHIHAMACHO',
#  'DISTRITODEBESIKO',
#  'CABRALES',
#  '围龙',
#  'KANGKONG',
#  'FAERDERKOMMUNE',
#  'STADTTEILBLOCKLAND',
#  'CONCEICAODOMATODENTRO',
#  'DESAMULANGSARI',
#  'THIESREGION',
#  'DESAANAONEMBUTE',
#  '德恒隆',
#  'DESASLEMANLOR',
#  'KUCHENGTZU',
#  'بيتالعلي',
#  'DAERAHTINGKATIIKAPUASHULU',
#  'DESABLEBER',
#  'KOMUNAEKOTES',
#  'FANGSHIPING',
#  'FENGLINGDU',
#  'قەزاىپێنجوێن',
#  'QUZHOUXIAN',
#  '掇刀',
#  'LANDKREISMAINSPESSART',
#  'HUANGLONGXIANG',
#  'BHIMPEDI',
#  'BULAOTUNZHEN',
#  '官塘桥乡',
#  'DESAKLUMUTAN',
#  'WENGGONGNAOERSUMU',
#  'ZHAMBYLQALASY',
#  'DICLEBUCAGI',
#  'سارتام',
#  'ZORTEA',
#  'BOUVIGNESSURMEUSE',
#  'NYAMIHONDI',
#  'SEOGYODONG',
#  '克城',
#  'KAMPUNGSELEMAMA',
#  'TZUHSINTSUN',
#  'XAHIENKIET',
#  'DANBAN',
#  'SOUTHKANARA',
#  'KAMPUNGTARAWI',
#  'MUNICIPIODEPUERTOBOYACA',
#  'DESASUMURJALAK',
#  'DESATOTABUAN',
#  '大苏吉',
#  'DEDGAU',
#  '三屯营',
#  '泡石淀',
#  'DESAPASMAMAMBU',
#  'ITOMANMACHI',
#  'NOVELE',
#  'قانية',
#  'MEEKSI',
#  'DEPARTEMENTDENGOURKOSSO',
#  'TIPTIP',
#  '龙脊',
#  'KAMPUNGUWEONAGEI',
#  'SHEYANGHSIEN',
#  'BOMSUCESSODEITARARE',
#  'COMUNABOBU',
#  'POVAZSKABYSTRICADISTRICT',
#  'GADUNGAIR',
#  'HACHISHOSHICHO',
#  'DESACEMPLANG',
#  'BARTRINGEN',
#  '吉卡',
#  'KOSHIDEKHA',
#  'RACEFRAM',
#  'MAGOE',
#  '民和',
#  'MUNICIPIODEJARDIN',
#  'DESADARAWOLONG',
#  'THITRANBANYENNHAN',
#  'COMUNASANGERU',
#  'KELURAHANKASABOLO',
#  'MIYAKOSHI',
#  'PADWATPARISH',
#  'قيادةأضار',
#  'DESADARANUTARA',
#  'ZHUGUDONG',
#  'YUTSUITO',
#  '淳化镇',
#  'KAMPUNGHOKOLEKMA',
#  'KECAMATANNANGAPADA',
#  '绰霍尔乡',
#  'ALMASHKI',
#  '汤庄镇',
#  'BARRICHIEFDOM',
#  '古楼镇',
#  '강선로동자구',
#  'COMUNABABENI',
#  '苏河乡',
#  'XIANCHIYU',
#  'REGIONDUBORKOUENNEDITIBESTI',
#  'DESASATRA',
#  'おおさとちょう',
#  'LICAB',
#  'MUNSINILTONG',
#  'DESALIMUSNUNGGAL',
#  'KARAMPAHAM',
#  'DESATIMBONG',
#  'LONGHUSHANZHEN',
#  '定东',
#  'POTOUQU',
#  '王店乡',
#  'COMUNAVARVORU',
#  'RIODASANTAS',
#  'BUYUKKOYBUCAGI',
#  'PREMIERESECTIONCOMMUNALERIVIEREDESNEGRES',
#  'マツマエチョウ',
#  '金口河区',
#  'TAIJIMIAO',
#  'DESAMUNGGUR',
#  '希伯花',
#  'KELURAHANMANGGARBARU',
#  'TABORAMUNICIPALCOUNCIL',
#  'eEBEZINI',
#  'KAMPUNGMABUME',
#  'XABINHQUOI',
#  '星甸镇',
#  '皮石乡',
#  'بلديةالشمال',
#  'AMPHOEMAESUAI',
#  'СумськаОбласть',
#  'DIANPING',
#  '三道关',
#  'BUCHANG',
#  'JANGBALRI',
#  'LABUPUXIANG',
#  'DABUBAWIQAYEHBAHRI',
#  'OPSTINALUDBREG',
#  'DESAWIDOROKANDANG',
#  'MUNICIPIODEMOCTEZUMA',
#  'MWANDIGA',
#  'SUMBABARATDAYA',
#  '陈袁滩',
#  'LINGDIXIANG',
#  'SUD',
#  'BAEKSEOKEUP',
#  '田庄台镇',
#  'BHIR',
#  'DELEGATIONDEFOUSSANA',
#  'XADONGSANG',
#  '乌素图乡',
#  '傅家镇',
#  '尚德乡',
#  'QABQIRJIEDAO',
#  'TUNGHOHSIEN',
#  'KINGAMPHOENONSUWAN',
#  'ALMUDAYBI',
#  'PARCHIM',
#  'MUNICIPIODEJOSEJOAQUINDEHERRERA',
#  'KILAKCOUNTY',
#  'BEZIRKBADEN',
#  '观水镇',
#  'TADAOKAMURA',
#  'THITRANHUNGLOI',
#  'MUNICIPIODEXICOTLAN',
#  '伊宁县',
#  '救兵乡',
#  'LEGONDPONTOUVRE',
#  'JINLI',
#  'WANGCHU',
#  'OKRESCHRUDIM',
#  'SAGASAKSUBLOCATION',
#  'PEDROVERA',
#  'AFFARALMIFTAH',
#  'شهرستانبهارستان',
#  'PATAHEWAHETADIVISION',
#  '城北镇',
#  'SHANTOUTING',
#  '渝水区',
#  'HSIAYUN',
#  'JIAOPINGDUXIANG',
#  'قضاءمليح',
#  'SHAOKUOYINGTZU',
#  'ОпштинаСокобања',
#  'ZHOUWANGCUN',
#  '定襄',
#  'PONONGPEQUENO',
#  'NORTHDUMFRIES',
#  'DESATAWING',
#  'COMUNEDISANCANZIANDISONZO',
#  'DESAKALIMANGGIS',
#  'NANAFUKUMURA',
#  'XAXUANTO',
#  '李店乡',
#  'YUNNINCHEN',
#  '河溜镇',
#  'DESASALUTAMBUNG',
#  'ЧАРОДИНСКИЙРАЙОН',
#  'LENVIK',
#  'KELURAHANPANIKIBAWAH',
#  'PRIARGUNSKIYRAYON',
#  'JIAOZHUANG',
#  'DAHENG',
#  'GEMEENTEGRONSVELD',
#  'RETALHULEU',
#  '园洲',
#  'TAOHSIN',
#  'QIYADATAYITUMAYRAH',
#  'PENGHUCOUNTY',
#  'SHIMBI',
#  'BAOYIZHEN',
#  'NISSEDALKOMMUNE',
#  'DANJIAMIAOZHEN',
#  'HSIAPAISHIH',
#  'FOURTHDIVISION',
#  'FUCHENGHSU',
#  'TORIKAMIMURA',
#  ...}

# %% [markdown]
# Match words in the textfile with placenames in the gazetteer. There is a moving window that can be set with the variable num_words. Only words that don't appear in the 500 most frequent word list get added.

# %%
# create a set that only contains placenames that are not in the most common words set
placenames_set = {placename for placename in placenames if placename not in common_set}


# create empty list that is filled with the matched placenames
af_matches = []
# define size of moving window
num_words = 6


skip_count = -999
# loop through the words of the text
for i, word in enumerate(allWords):

    # the amount of words that the last placename match consisted of is skipped
    # e.g. "united states" and "states" would be two matches otherwise 
    skip_count -= 1
    if skip_count >= 0:
        continue

    try:
        nWords = [nword for nword in allWords[i : i+num_words]]

        # take the current n words (moving window) and create all possible concatenations that contain the last word
        # if there is a match, all words that where in the moving window are skipped
        for j in range(num_words-1, -1, -1):
            if gaz == "nga":
                tmp_words = "".join( [word.upper() for word in nWords[:j+1]] )
            if gaz in ["geonames", "countries"]:
                tmp_words = " ".join( [word.strip() for word in nWords[:j+1] ])

            # print(tmp_words)

            if tmp_words in placenames_set:
                af_matches.append(tmp_words)
                skip_count = j
                break

    except IndexError as e:
        print(e)
        break

# %% [markdown]
# Create Dictionary with the matched placenames as keys and dictionaries with the counts as values.

# %%
d = {}
len_af_matches = len(af_matches)

for i, match in enumerate(af_matches):
    if match in d.keys():
        d[match]["count"] += 1
    else:
        d[match] = {"count": 1}

# %% [markdown]
# Fill the dictionary with the coordinates of the placenames.

# %%
lenKeys = len(d)
logInterval = 1 #int(round(lenKeys/20, 0))

for i, (placename, attributes) in enumerate(d.items()):

    tmp_df_values = df_gazetteer.query(f"{nameCol} == @placename").values[0]
    # tmp_df_values = df_gazetteer[df_gazetteer["SORT_NAME_RO"] == "MAFIKENG"].values[0]
    attributes["lat"] = tmp_df_values[indexOfLat]
    attributes["lon"] = tmp_df_values[indexOfLon]

    # give feedback to progress
    
    if (i+1 % logInterval == 0 and i > 0) or i+1 == lenKeys:
        print(f"{i+1} of {lenKeys} ({round((i/lenKeys)*100, 1)}%)", end='\r')
# Out:
# 100 of 100 (99.0%)

# %%
lyst = []

for word in common_set:
    # bool = df_gazetteer[nameCol].str.contains(word, case=False)
    # if bool.sum() > 1:
    if word in placenames_set:
        lyst.append(word)

# %% [markdown]
# Create a geodataframe with the matched placenames

# %%
df = pd.DataFrame(
    [ [place] + list(attributes.values()) for place, attributes in d.items()],
    columns=["name", "count", "lat", "lon"])

geo = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df.lon, df.lat),
    crs=4326
)

# geojsonname = textfile[textfile.find("/")+1:textfile.find(".")][6:]
# geo.to_file(f"data/geodataframes/{geojsonname}.geojson", driver='GeoJSON')

geo.head()
# Out:
#       name  count        lat         lon                    geometry
# 0      ADE      1  12.456154   22.240731   POINT (22.24073 12.45615)
# 1      ASA     21  27.782400  101.764000  POINT (101.76400 27.78240)
# 2   PUBLIC     10   7.688139  124.774652   POINT (124.77465 7.68814)
# 3  READING      2  51.450000   -0.966667   POINT (-0.96667 51.45000)
# 4     ITIS     21  60.927418   26.280911   POINT (26.28091 60.92742)

# %%
pointMap = folium.Figure(width='35%')
gpd.GeoSeries.explore(
    geo,
    max_bounds=True,
    tiles="Open Street Map", # "Stamen Watercolor",
    marker_type='circle',
    marker_kwds={'radius': 50000,
    'fill': True}).add_to(pointMap)

# folium.TileLayer(tiles='stamen watercolor', name="Watercolor").add_to(pointMap)

pointMap
# Out:
# <div style="width:35%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_81ef635103a148308b1d1a3b486ce559%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
from folium import plugins

# extract coordinate of geodataframe
coordinates = [[point.xy[1][0], point.xy[0][0]] for point in geo.geometry]

# create map
heatMap = folium.Figure(width='35%')
heatMap = folium.Map(location = [15,30], zoom_start = 2, tiles=None).add_to(heatMap)

# add tiles
folium.TileLayer(tiles='Cartodb dark_matter', name="Dark").add_to(heatMap)
folium.TileLayer(tiles='stamen watercolor', name="Watercolor").add_to(heatMap)

# add points and markercluster
points = folium.FeatureGroup(name="Points", show=False).add_to(heatMap)
cluster = plugins.MarkerCluster(name="Cluster").add_to(heatMap)
for coordinate in coordinates:
    folium.Circle(coordinate).add_to(cluster)
    folium.Circle(coordinate).add_to(points)

# add heatmap
plugins.HeatMap(
    name = 'HeatMap',
    data = coordinates,
    min_opacity = 0.3
    ).add_to(heatMap)

# add layercontrol
folium.LayerControl(collapsed=False).add_to(heatMap)


heatMap
# Out:
# <div style="width:35%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_175d39ade62d4045bb09ec26c65d0072%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20% ...
