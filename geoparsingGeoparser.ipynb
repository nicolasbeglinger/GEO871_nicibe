# %%
from mordecai import Geoparser

# %%
geo = Geoparser()
# Out:
# Models path: /Users/nicibe/miniconda3/envs/mordecai/lib/python3.7/site-packages/mordecai/models/
# 2021-12-20 22:34:36.055030: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GET http://localhost:9200/geonames/_count [status:N/A request:0.016s]
# Traceback (most recent call last):
#   File "/Users/nicibe/miniconda3/envs/mordecai/lib/python3.7/site-packages/urllib3/connection.py", line 175, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "/Users/nicibe/miniconda3/envs/mordecai/lib/python3.7/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
# ...

# %%
geo.geoparse("Eiffel Tower is located in Paris")
